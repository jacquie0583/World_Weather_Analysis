# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# Files to load
avg_rain_state_data_to_load = os.path.join("~/Desktop/Class Folder/Resources/avg_rain_state_data.csv")

# Read the donor data file and store it in a Pandas DataFrame.
avg_rain_state_data_df = pd.read_csv(avg_rain_state_data_to_load)
avg_rain_state_data_df
# Out:
#              State  Inches  Milli­metres  Rank  Unnamed: 4  Unnamed: 5  \
# 0          Alabama    58.3          1480     4         NaN         NaN
# 1           Alaska    22.5           572    39         NaN         NaN
# 2          Arizona    13.6           345    47         NaN         NaN
# 3         Arkansas    50.6          1284     8         NaN         NaN
# 4       California    22.2           563    40         NaN         NaN
# 5         Colorado    15.9           405    44         NaN         NaN
# 6      Connecticut    50.3          1279     9         NaN         NaN
# 7         Delaware    45.7          1160    16         NaN         NaN
# 8          Florida    54.5          1385     5         NaN         NaN
# 9          Georgia    50.7          1287     7         NaN         NaN
# 10          Hawaii    63.7          1618     1         NaN         NaN
# 11           Idaho    18.9           481    42         NaN         NaN
# ...

# %%
avg_rain_state_data_df.groupby(['Rank'],sort = True, ascending = True)
avg_rain_state_data_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-28d3566a2ea5> in <module>
# ----> 1 avg_rain_state_data_df.groupby(['Rank'],sort = True, ascending = True)
#       2 avg_rain_state_data_df
#
# TypeError: groupby() got an unexpected keyword argument 'ascending'

# %%
# Create graph
x_axis = np.arange(len(df))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))

# %%
plt.bar(x_axis, df["Inches"])
plt.xticks(tick_locations, df["State"], rotation = len(df["State"])

# %%
plt.title("Rain in Inches by State")
plt.xlabel("State")
plt.ylabel("Rain (inches)")
plt.show()
