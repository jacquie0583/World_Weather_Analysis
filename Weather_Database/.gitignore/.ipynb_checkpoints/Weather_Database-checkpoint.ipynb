# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
#%pip install citipy
from citipy import citipy

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5c2f444c3abc91cc9e7680de5088257'

# %%
#cut from starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | wad rawah
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | dawlatabad
# Processing Record 7 of Set 1 | cassilandia
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | tanshui
# City not found. Skipping...
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | pingliang
# Processing Record 13 of Set 1 | celestun
# Processing Record 14 of Set 1 | sibolga
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | mayumba
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | port hardy
# Processing Record 26 of Set 1 | isangel
# Processing Record 27 of Set 1 | santa marta
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | elko
# Processing Record 31 of Set 1 | sabla
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | ondjiva
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | pangkalanbuun
# Processing Record 41 of Set 1 | ouango
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | kabare
# Processing Record 50 of Set 1 | nalut
# Processing Record 1 of Set 2 | chara
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | adre
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | tambovka
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | moose factory
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | teknaf
# Processing Record 12 of Set 2 | seguela
# Processing Record 13 of Set 2 | antalaha
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | tahe
# Processing Record 16 of Set 2 | cockburn town
# Processing Record 17 of Set 2 | havre-saint-pierre
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | san rafael
# Processing Record 20 of Set 2 | naron
# Processing Record 21 of Set 2 | mount isa
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | arinos
# Processing Record 25 of Set 2 | wuwei
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | gornopravdinsk
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | beisfjord
# Processing Record 32 of Set 2 | nador
# Processing Record 33 of Set 2 | bara
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | saint-pierre
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | honiara
# Processing Record 38 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 2 | batagay-alyta
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | general pico
# Processing Record 42 of Set 2 | ola
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | te anau
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | bontang
# Processing Record 49 of Set 2 | sharqpur
# Processing Record 50 of Set 2 | atar
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | bloomsburg
# Processing Record 3 of Set 3 | raudeberg
# Processing Record 4 of Set 3 | toungoo
# City not found. Skipping...
# Processing Record 5 of Set 3 | aonla
# Processing Record 6 of Set 3 | zhigansk
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | sisimiut
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | kyren
# Processing Record 11 of Set 3 | sahbuz
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 3 | abonnema
# Processing Record 16 of Set 3 | sitka
# Processing Record 17 of Set 3 | mooi river
# City not found. Skipping...
# Processing Record 18 of Set 3 | beian
# Processing Record 19 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 3 | matata
# Processing Record 21 of Set 3 | rocha
# Processing Record 22 of Set 3 | qarqin
# Processing Record 23 of Set 3 | khasan
# Processing Record 24 of Set 3 | dakar
# Processing Record 25 of Set 3 | bubaque
# Processing Record 26 of Set 3 | daru
# Processing Record 27 of Set 3 | balkanabat
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | camana
# Processing Record 30 of Set 3 | huangzhai
# Processing Record 31 of Set 3 | marsh harbour
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | byron bay
# Processing Record 36 of Set 3 | hilo
# Processing Record 37 of Set 3 | lompoc
# Processing Record 38 of Set 3 | jalu
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | maues
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | la rioja
# Processing Record 43 of Set 3 | waipawa
# Processing Record 44 of Set 3 | vestmannaeyjar
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | mantua
# Processing Record 47 of Set 3 | flinders
# Processing Record 48 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | kargil
# Processing Record 2 of Set 4 | kenai
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 4 | seoul
# Processing Record 7 of Set 4 | yar-sale
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | poum
# Processing Record 11 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 4 | kualakapuas
# Processing Record 13 of Set 4 | muli
# Processing Record 14 of Set 4 | umm kaddadah
# Processing Record 15 of Set 4 | necochea
# Processing Record 16 of Set 4 | muhos
# Processing Record 17 of Set 4 | vulcan
# Processing Record 18 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 4 | barraute
# Processing Record 20 of Set 4 | grindavik
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | bedford
# Processing Record 23 of Set 4 | buraydah
# Processing Record 24 of Set 4 | ucluelet
# Processing Record 25 of Set 4 | phuket
# Processing Record 26 of Set 4 | the valley
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | bereda
# Processing Record 29 of Set 4 | chokurdakh
# Processing Record 30 of Set 4 | muika
# City not found. Skipping...
# Processing Record 31 of Set 4 | black river
# Processing Record 32 of Set 4 | victoria
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | mae sai
# Processing Record 35 of Set 4 | sinnamary
# Processing Record 36 of Set 4 | kloulklubed
# Processing Record 37 of Set 4 | acapulco
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | trelew
# Processing Record 41 of Set 4 | chirongui
# Processing Record 42 of Set 4 | dondo
# Processing Record 43 of Set 4 | caravelas
# Processing Record 44 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | sandpoint
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 4 | mumford
# Processing Record 50 of Set 4 | san cristobal
# Processing Record 1 of Set 5 | yumen
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | mareeba
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | port-gentil
# Processing Record 7 of Set 5 | beloha
# Processing Record 8 of Set 5 | semporna
# Processing Record 9 of Set 5 | severo-kurilsk
# Processing Record 10 of Set 5 | uruzgan
# Processing Record 11 of Set 5 | erechim
# Processing Record 12 of Set 5 | socorro
# Processing Record 13 of Set 5 | kopervik
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | winona
# Processing Record 16 of Set 5 | uige
# Processing Record 17 of Set 5 | longyearbyen
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | bhainsdehi
# Processing Record 20 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 5 | richards bay
# Processing Record 22 of Set 5 | asau
# Processing Record 23 of Set 5 | plettenberg bay
# Processing Record 24 of Set 5 | erenhot
# Processing Record 25 of Set 5 | pokhara
# Processing Record 26 of Set 5 | harindanga
# Processing Record 27 of Set 5 | port augusta
# Processing Record 28 of Set 5 | wanning
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | jiangyou
# Processing Record 31 of Set 5 | shingu
# Processing Record 32 of Set 5 | khash
# Processing Record 33 of Set 5 | villarrobledo
# Processing Record 34 of Set 5 | prince george
# Processing Record 35 of Set 5 | victor harbor
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | ishigaki
# Processing Record 38 of Set 5 | rolante
# Processing Record 39 of Set 5 | pechory
# Processing Record 40 of Set 5 | mazatlan
# Processing Record 41 of Set 5 | bardiyah
# Processing Record 42 of Set 5 | sao filipe
# Processing Record 43 of Set 5 | tiznit
# Processing Record 44 of Set 5 | najran
# Processing Record 45 of Set 5 | capoterra
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | airai
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | partapur
# Processing Record 50 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 6 | georgetown
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | san matias
# Processing Record 5 of Set 6 | saint-philippe
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | xichang
# Processing Record 8 of Set 6 | kachug
# Processing Record 9 of Set 6 | obera
# Processing Record 10 of Set 6 | ambilobe
# Processing Record 11 of Set 6 | banda aceh
# Processing Record 12 of Set 6 | lorengau
# Processing Record 13 of Set 6 | loding
# Processing Record 14 of Set 6 | talnakh
# Processing Record 15 of Set 6 | tananger
# Processing Record 16 of Set 6 | atibaia
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | west bay
# Processing Record 19 of Set 6 | kodinsk
# Processing Record 20 of Set 6 | astoria
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | lata
# Processing Record 23 of Set 6 | colac
# Processing Record 24 of Set 6 | baruun-urt
# Processing Record 25 of Set 6 | newport
# Processing Record 26 of Set 6 | pingzhuang
# Processing Record 27 of Set 6 | comodoro rivadavia
# Processing Record 28 of Set 6 | ust-ishim
# Processing Record 29 of Set 6 | nome
# Processing Record 30 of Set 6 | cabo san lucas
# Processing Record 31 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 32 of Set 6 | kamaishi
# Processing Record 33 of Set 6 | kieta
# Processing Record 34 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 6 | playa vicente
# Processing Record 36 of Set 6 | hay river
# Processing Record 37 of Set 6 | omsukchan
# Processing Record 38 of Set 6 | raga
# Processing Record 39 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 6 | bandarbeyla
# Processing Record 41 of Set 6 | tilichiki
# Processing Record 42 of Set 6 | kaeo
# Processing Record 43 of Set 6 | antofagasta
# Processing Record 44 of Set 6 | muros
# Processing Record 45 of Set 6 | lithgow
# Processing Record 46 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 6 | fort nelson
# Processing Record 48 of Set 6 | myitkyina
# Processing Record 49 of Set 6 | tarakan
# Processing Record 50 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | sozimskiy
# Processing Record 2 of Set 7 | kudahuvadhoo
# Processing Record 3 of Set 7 | jiazi
# Processing Record 4 of Set 7 | lazaro cardenas
# Processing Record 5 of Set 7 | ha tinh
# Processing Record 6 of Set 7 | pachino
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | guerrero
# Processing Record 9 of Set 7 | tlanchinol
# Processing Record 10 of Set 7 | hasaki
# Processing Record 11 of Set 7 | kavaratti
# Processing Record 12 of Set 7 | emba
# Processing Record 13 of Set 7 | arkhangelsk
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | chernyshevskiy
# Processing Record 16 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 17 of Set 7 | venice
# Processing Record 18 of Set 7 | havoysund
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | cabedelo
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | mayo
# Processing Record 23 of Set 7 | oistins
# Processing Record 24 of Set 7 | lagoa
# Processing Record 25 of Set 7 | savannah bight
# Processing Record 26 of Set 7 | kuala terengganu
# Processing Record 27 of Set 7 | seabra
# Processing Record 28 of Set 7 | wilmington
# Processing Record 29 of Set 7 | deputatskiy
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | skjaerhollen
# City not found. Skipping...
# Processing Record 32 of Set 7 | palmer
# Processing Record 33 of Set 7 | kargasok
# Processing Record 34 of Set 7 | natal
# Processing Record 35 of Set 7 | emerald
# Processing Record 36 of Set 7 | guiratinga
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | talah
# City not found. Skipping...
# Processing Record 39 of Set 7 | maymyo
# Processing Record 40 of Set 7 | oranjemund
# Processing Record 41 of Set 7 | gaziantep
# Processing Record 42 of Set 7 | sakakah
# Processing Record 43 of Set 7 | sur
# Processing Record 44 of Set 7 | kovvur
# Processing Record 45 of Set 7 | batemans bay
# Processing Record 46 of Set 7 | bocholt
# Processing Record 47 of Set 7 | baykit
# Processing Record 48 of Set 7 | kanniyakumari
# Processing Record 49 of Set 7 | touros
# Processing Record 50 of Set 7 | paraiso
# Processing Record 1 of Set 8 | viedma
# Processing Record 2 of Set 8 | torbay
# Processing Record 3 of Set 8 | verkhoyansk
# Processing Record 4 of Set 8 | stokmarknes
# Processing Record 5 of Set 8 | sabang
# Processing Record 6 of Set 8 | benguela
# Processing Record 7 of Set 8 | puerto ayacucho
# Processing Record 8 of Set 8 | rawson
# Processing Record 9 of Set 8 | conceicao do castelo
# Processing Record 10 of Set 8 | road town
# Processing Record 11 of Set 8 | bani
# Processing Record 12 of Set 8 | hobyo
# Processing Record 13 of Set 8 | kholodnyy
# Processing Record 14 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 8 | ganta
# Processing Record 16 of Set 8 | muriwai beach
# Processing Record 17 of Set 8 | chapais
# Processing Record 18 of Set 8 | lavrentiya
# Processing Record 19 of Set 8 | bundaberg
# Processing Record 20 of Set 8 | mao
# Processing Record 21 of Set 8 | pisco
# Processing Record 22 of Set 8 | chicama
# Processing Record 23 of Set 8 | margate
# Processing Record 24 of Set 8 | dwarka
# Processing Record 25 of Set 8 | mudanjiang
# Processing Record 26 of Set 8 | saint-joseph
# Processing Record 27 of Set 8 | opuwo
# Processing Record 28 of Set 8 | corrente
# Processing Record 29 of Set 8 | qasigiannguit
# Processing Record 30 of Set 8 | opunake
# Processing Record 31 of Set 8 | marawi
# Processing Record 32 of Set 8 | aklavik
# Processing Record 33 of Set 8 | biak
# Processing Record 34 of Set 8 | provideniya
# Processing Record 35 of Set 8 | tomatlan
# Processing Record 36 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 37 of Set 8 | ufimskiy
# Processing Record 38 of Set 8 | akyab
# Processing Record 39 of Set 8 | tiksi
# Processing Record 40 of Set 8 | freetown
# Processing Record 41 of Set 8 | novyye burasy
# Processing Record 42 of Set 8 | andenes
# Processing Record 43 of Set 8 | jiuquan
# Processing Record 44 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 8 | caterman
# Processing Record 46 of Set 8 | jaffrey
# Processing Record 47 of Set 8 | parksville
# Processing Record 48 of Set 8 | kavieng
# Processing Record 49 of Set 8 | nemuro
# Processing Record 50 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 1 of Set 9 | port keats
# Processing Record 2 of Set 9 | aanekoski
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | saint-augustin
# Processing Record 5 of Set 9 | anloga
# Processing Record 6 of Set 9 | shahr-e kord
# Processing Record 7 of Set 9 | makakilo city
# Processing Record 8 of Set 9 | manama
# Processing Record 9 of Set 9 | ariquemes
# Processing Record 10 of Set 9 | nsoko
# Processing Record 11 of Set 9 | ossora
# Processing Record 12 of Set 9 | maarianhamina
# Processing Record 13 of Set 9 | sayyan
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | bonavista
# Processing Record 16 of Set 9 | ternate
# Processing Record 17 of Set 9 | sorland
# Processing Record 18 of Set 9 | la ronge
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | college
# Processing Record 21 of Set 9 | shakawe
# Processing Record 22 of Set 9 | lasa
# Processing Record 23 of Set 9 | zeya
# Processing Record 24 of Set 9 | turbat
# Processing Record 25 of Set 9 | chenghai
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | houston
# Processing Record 28 of Set 9 | kiknur
# Processing Record 29 of Set 9 | ponta delgada
# Processing Record 30 of Set 9 | juneau
# Processing Record 31 of Set 9 | falmouth
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | mandera
# Processing Record 34 of Set 9 | thiruvananthapuram
# Processing Record 35 of Set 9 | tokur
# Processing Record 36 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 9 | paita
# Processing Record 38 of Set 9 | albanel
# Processing Record 39 of Set 9 | hualmay
# Processing Record 40 of Set 9 | miri
# Processing Record 41 of Set 9 | faanui
# Processing Record 42 of Set 9 | burns lake
# Processing Record 43 of Set 9 | mungwi
# Processing Record 44 of Set 9 | vardo
# Processing Record 45 of Set 9 | matamoros
# Processing Record 46 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 9 | bursa
# Processing Record 48 of Set 9 | juegang
# Processing Record 49 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 50 of Set 9 | mwene-ditu
# Processing Record 1 of Set 10 | souillac
# Processing Record 2 of Set 10 | itoman
# Processing Record 3 of Set 10 | khuzhir
# Processing Record 4 of Set 10 | montrose
# Processing Record 5 of Set 10 | pyay
# Processing Record 6 of Set 10 | marau
# Processing Record 7 of Set 10 | estacion coahuila
# Processing Record 8 of Set 10 | zhangye
# Processing Record 9 of Set 10 | hervey bay
# Processing Record 10 of Set 10 | oriximina
# Processing Record 11 of Set 10 | acarau
# Processing Record 12 of Set 10 | nong bua
# Processing Record 13 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 10 | sept-iles
# Processing Record 15 of Set 10 | pandan
# Processing Record 16 of Set 10 | teguise
# Processing Record 17 of Set 10 | buribay
# Processing Record 18 of Set 10 | labuhan
# Processing Record 19 of Set 10 | vaitape
# Processing Record 20 of Set 10 | ocampo
# Processing Record 21 of Set 10 | samarai
# Processing Record 22 of Set 10 | nantucket
# Processing Record 23 of Set 10 | egvekinot
# Processing Record 24 of Set 10 | lokosovo
# Processing Record 25 of Set 10 | yinchuan
# Processing Record 26 of Set 10 | gazanjyk
# Processing Record 27 of Set 10 | lewisporte
# Processing Record 28 of Set 10 | luderitz
# Processing Record 29 of Set 10 | hurghada
# Processing Record 30 of Set 10 | estelle
# Processing Record 31 of Set 10 | bereznik
# Processing Record 32 of Set 10 | sabha
# Processing Record 33 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 34 of Set 10 | krasnoselkup
# Processing Record 35 of Set 10 | tungor
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | barcelos
# Processing Record 38 of Set 10 | nuuk
# Processing Record 39 of Set 10 | nanchang
# Processing Record 40 of Set 10 | itarema
# Processing Record 41 of Set 10 | luwuk
# Processing Record 42 of Set 10 | adrar
# Processing Record 43 of Set 10 | gimli
# Processing Record 44 of Set 10 | nkayi
# Processing Record 45 of Set 10 | obo
# Processing Record 46 of Set 10 | nishihara
# Processing Record 47 of Set 10 | goderich
# Processing Record 48 of Set 10 | patnanungan
# Processing Record 49 of Set 10 | sorong
# Processing Record 50 of Set 10 | kamenka
# Processing Record 1 of Set 11 | akonolinga
# Processing Record 2 of Set 11 | dalbandin
# Processing Record 3 of Set 11 | buenaventura
# Processing Record 4 of Set 11 | mto wa mbu
# Processing Record 5 of Set 11 | toba
# Processing Record 6 of Set 11 | jintur
# Processing Record 7 of Set 11 | bud
# Processing Record 8 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 11 | coquimbo
# Processing Record 10 of Set 11 | demidov
# Processing Record 11 of Set 11 | okhotsk
# Processing Record 12 of Set 11 | kjollefjord
# Processing Record 13 of Set 11 | arrecife
# Processing Record 14 of Set 11 | sehithwa
# Processing Record 15 of Set 11 | tete
# Processing Record 16 of Set 11 | yeppoon
# Processing Record 17 of Set 11 | aden
# Processing Record 18 of Set 11 | marquette
# Processing Record 19 of Set 11 | saint-tite
# Processing Record 20 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 11 | grand gaube
# Processing Record 22 of Set 11 | peruibe
# Processing Record 23 of Set 11 | camaqua
# Processing Record 24 of Set 11 | pandamatenga
# Processing Record 25 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 11 | peace river
# Processing Record 27 of Set 11 | cantapoy
# Processing Record 28 of Set 11 | chotila
# Processing Record 29 of Set 11 | bilma
# Processing Record 30 of Set 11 | poronaysk
# Processing Record 31 of Set 11 | calama
# Processing Record 32 of Set 11 | codajas
# Processing Record 33 of Set 11 | naze
# Processing Record 34 of Set 11 | qitaihe
# Processing Record 35 of Set 11 | sambava
# Processing Record 36 of Set 11 | ilek
# Processing Record 37 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 11 | jiayuguan
# Processing Record 39 of Set 11 | bongandanga
# Processing Record 40 of Set 11 | diffa
# Processing Record 41 of Set 11 | creston
# Processing Record 42 of Set 11 | steubenville
# Processing Record 43 of Set 11 | maumere
# Processing Record 44 of Set 11 | san jeronimo
# Processing Record 45 of Set 11 | dudinka
# Processing Record 46 of Set 11 | nushki
# Processing Record 47 of Set 11 | chandia
# Processing Record 48 of Set 11 | haapiti
# Processing Record 49 of Set 11 | georgiyevka
# Processing Record 50 of Set 11 | gorontalo
# Processing Record 1 of Set 12 | alofi
# Processing Record 2 of Set 12 | constitucion
# Processing Record 3 of Set 12 | oberkirch
# Processing Record 4 of Set 12 | haines junction
# Processing Record 5 of Set 12 | alice springs
# Processing Record 6 of Set 12 | kasempa
# Processing Record 7 of Set 12 | grand-santi
# Processing Record 8 of Set 12 | vestmanna
# Processing Record 9 of Set 12 | monrovia
# Processing Record 10 of Set 12 | ventimiglia
# Processing Record 11 of Set 12 | steamboat springs
# Processing Record 12 of Set 12 | sonoita
# Processing Record 13 of Set 12 | ranau
# Processing Record 14 of Set 12 | carroll
# Processing Record 15 of Set 12 | ranong
# Processing Record 16 of Set 12 | makat
# Processing Record 17 of Set 12 | iisaku
# Processing Record 18 of Set 12 | pontianak
# Processing Record 19 of Set 12 | bathsheba
# Processing Record 20 of Set 12 | chiredzi
# Processing Record 21 of Set 12 | sernur
# Processing Record 22 of Set 12 | winnemucca
# Processing Record 23 of Set 12 | esmeraldas
# Processing Record 24 of Set 12 | avera
# Processing Record 25 of Set 12 | finschhafen
# Processing Record 26 of Set 12 | gannan
# Processing Record 27 of Set 12 | oskarshamn
# Processing Record 28 of Set 12 | waitati
# Processing Record 29 of Set 12 | mahibadhoo
# Processing Record 30 of Set 12 | homer
# Processing Record 31 of Set 12 | saint-pierre-des-corps
# Processing Record 32 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 12 | atambua
# Processing Record 34 of Set 12 | hailar
# Processing Record 35 of Set 12 | alyangula
# Processing Record 36 of Set 12 | nyurba
# Processing Record 37 of Set 12 | hanstholm
# Processing Record 38 of Set 12 | verkhnyaya inta
# Processing Record 39 of Set 12 | swan hill
# Processing Record 40 of Set 12 | novyy urengoy
# Processing Record 41 of Set 12 | mainaguri
# Processing Record 42 of Set 12 | eqbaliyeh
# Processing Record 43 of Set 12 | excelsior springs
# Processing Record 44 of Set 12 | hede
# Processing Record 45 of Set 12 | vanimo
# Processing Record 46 of Set 12 | mangrol
# Processing Record 47 of Set 12 | kalat
# Processing Record 48 of Set 12 | langarud
# Processing Record 49 of Set 12 | goundam
# Processing Record 50 of Set 12 | itaituba
# Processing Record 1 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 13 | mangan
# Processing Record 3 of Set 13 | belgrade
# Processing Record 4 of Set 13 | evensk
# Processing Record 5 of Set 13 | sarangani
# Processing Record 6 of Set 13 | chubbuck
# Processing Record 7 of Set 13 | rio grande
# Processing Record 8 of Set 13 | dinguiraye
# Processing Record 9 of Set 13 | ginda
# Processing Record 10 of Set 13 | piet retief
# Processing Record 11 of Set 13 | aripuana
# Processing Record 12 of Set 13 | ennigerloh
# Processing Record 13 of Set 13 | tura
# Processing Record 14 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 13 | kirakira
# Processing Record 16 of Set 13 | sinjai
# Processing Record 17 of Set 13 | otjiwarongo
# Processing Record 18 of Set 13 | pirojpur
# Processing Record 19 of Set 13 | jizan
# Processing Record 20 of Set 13 | tra vinh
# Processing Record 21 of Set 13 | ajdabiya
# Processing Record 22 of Set 13 | syke
# Processing Record 23 of Set 13 | aasiaat
# Processing Record 24 of Set 13 | gitega
# Processing Record 25 of Set 13 | lac du bonnet
# Processing Record 26 of Set 13 | aleksandrov gay
# Processing Record 27 of Set 13 | russell
# Processing Record 28 of Set 13 | port-cartier
# Processing Record 29 of Set 13 | inhambane
# Processing Record 30 of Set 13 | kalininsk
# Processing Record 31 of Set 13 | skibbereen
# Processing Record 32 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 13 | axim
# Processing Record 34 of Set 13 | kupang
# Processing Record 35 of Set 13 | preeceville
# Processing Record 36 of Set 13 | namtsy
# Processing Record 37 of Set 13 | iguape
# Processing Record 38 of Set 13 | luanda
# Processing Record 39 of Set 13 | trairi
# Processing Record 40 of Set 13 | mana
# Processing Record 41 of Set 13 | fukue
# Processing Record 42 of Set 13 | wagar
# Processing Record 43 of Set 13 | lagos
# Processing Record 44 of Set 13 | turkan
# Processing Record 45 of Set 13 | korla
# Processing Record 46 of Set 13 | pervomayskoye
# Processing Record 47 of Set 13 | la palma
# Processing Record 48 of Set 13 | rexburg
# Processing Record 49 of Set 13 | ketchikan
# Processing Record 50 of Set 13 | las vegas
# Processing Record 1 of Set 14 | nadvoitsy
# Processing Record 2 of Set 14 | sechura
# Processing Record 3 of Set 14 | cayenne
# Processing Record 4 of Set 14 | jaguariaiva
# Processing Record 5 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 6 of Set 14 | alugan
# Processing Record 7 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 14 | riyadh
# Processing Record 9 of Set 14 | olafsvik
# Processing Record 10 of Set 14 | rawlins
# Processing Record 11 of Set 14 | pundaguitan
# Processing Record 12 of Set 14 | puerto lempira
# Processing Record 13 of Set 14 | coihaique
# Processing Record 14 of Set 14 | robstown
# Processing Record 15 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 14 | utete
# Processing Record 17 of Set 14 | tara
# Processing Record 18 of Set 14 | saquarema
# Processing Record 19 of Set 14 | berberati
# Processing Record 20 of Set 14 | holland
# Processing Record 21 of Set 14 | tigil
# Processing Record 22 of Set 14 | bronnoysund
# Processing Record 23 of Set 14 | mandurah
# Processing Record 24 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 14 | cerrito
# Processing Record 26 of Set 14 | todiresti
# Processing Record 27 of Set 14 | xuddur
# Processing Record 28 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 14 | sao joao da barra
# Processing Record 30 of Set 14 | monte alegre
# Processing Record 31 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | lacolle
# Processing Record 33 of Set 14 | berezovyy
# Processing Record 34 of Set 14 | karlovo
# Processing Record 35 of Set 14 | arman
# Processing Record 36 of Set 14 | tucuma
# Processing Record 37 of Set 14 | ukiah
# Processing Record 38 of Set 14 | santa cruz
# Processing Record 39 of Set 14 | zanjan
# Processing Record 40 of Set 14 | high level
# Processing Record 41 of Set 14 | teya
# Processing Record 42 of Set 14 | henties bay
# Processing Record 43 of Set 14 | bitung
# Processing Record 44 of Set 14 | hutchinson
# Processing Record 45 of Set 14 | malindi
# Processing Record 46 of Set 14 | dedza
# Processing Record 47 of Set 14 | canutama
# Processing Record 48 of Set 14 | port lincoln
# Processing Record 49 of Set 14 | san francisco
# Processing Record 50 of Set 14 | tyukhtet
# Processing Record 1 of Set 15 | minoyan
# City not found. Skipping...
# Processing Record 2 of Set 15 | marienburg
# Processing Record 3 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 4 of Set 15 | gravdal
# Processing Record 5 of Set 15 | kosonsoy
# Processing Record 6 of Set 15 | turayf
# Processing Record 7 of Set 15 | prabumulih
# Processing Record 8 of Set 15 | genhe
# Processing Record 9 of Set 15 | uvarovka
# Processing Record 10 of Set 15 | mwense
# Processing Record 11 of Set 15 | kant
# Processing Record 12 of Set 15 | svetlogorsk
# Processing Record 13 of Set 15 | sistranda
# Processing Record 14 of Set 15 | tromso
# Processing Record 15 of Set 15 | sosua
# Processing Record 16 of Set 15 | thunder bay
# Processing Record 17 of Set 15 | whitehorse
# Processing Record 18 of Set 15 | praia da vitoria
# Processing Record 19 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 15 | puerto leguizamo
# Processing Record 21 of Set 15 | sawtell
# Processing Record 22 of Set 15 | kalangala
# Processing Record 23 of Set 15 | katobu
# Processing Record 24 of Set 15 | zhoucheng
# Processing Record 25 of Set 15 | esso
# Processing Record 26 of Set 15 | sumbe
# Processing Record 27 of Set 15 | santiago del estero
# Processing Record 28 of Set 15 | show low
# Processing Record 29 of Set 15 | miragoane
# Processing Record 30 of Set 15 | rafaela
# Processing Record 31 of Set 15 | sangareddi
# Processing Record 32 of Set 15 | oussouye
# Processing Record 33 of Set 15 | hongjiang
# Processing Record 34 of Set 15 | manta
# Processing Record 35 of Set 15 | hanzhong
# Processing Record 36 of Set 15 | noumea
# Processing Record 37 of Set 15 | waterboro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 675

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Wad Rawah  15.1603   33.1397     76.37        75         100       11.12
# 1         Lebu -37.6167  -73.6500     52.50        95         100        9.53
# 2      Ushuaia -54.8000  -68.3000     33.46        64          75       12.66
# 3     Khatanga  71.9667  102.5000     57.83        75         100        8.32
# 4   Dawlatabad  36.4141   64.9053     82.78        21          40        4.81
# 5  Cassilandia -19.1133  -51.7342     60.37        16          61        4.25
# 6     Hermanus -34.4187   19.2345     47.89        68          38       14.88
# 7  Tuktoyaktuk  69.4541 -133.0374     77.00        44           1       16.11
# 8    Pingliang  35.5392  106.6861     65.52        91          96        6.20
# 9     Celestun  20.8667  -90.4000     84.38        71           4       14.99
#
#   Current Description Country                 Date
# 0     overcast clouds      SD  2021-07-20 22:50:14
# 1     overcast clouds      CL  2021-07-20 22:43:18
# 2       broken clouds      AR  2021-07-20 22:43:12
# 3     overcast clouds      RU  2021-07-20 22:38:47
# 4    scattered clouds      AF  2021-07-20 22:46:20
# 5       broken clouds      BR  2021-07-20 22:50:15
# 6    scattered clouds      ZA  2021-07-20 22:43:05
# 7           clear sky      CA  2021-07-20 22:43:15
# 8     overcast clouds      CN  2021-07-20 22:50:16
# 9           clear sky      MX  2021-07-20 22:50:16

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Wad Rawah      SD  15.1603   33.1397     76.37        75         100
# 1         Lebu      CL -37.6167  -73.6500     52.50        95         100
# 2      Ushuaia      AR -54.8000  -68.3000     33.46        64          75
# 3     Khatanga      RU  71.9667  102.5000     57.83        75         100
# 4   Dawlatabad      AF  36.4141   64.9053     82.78        21          40
# 5  Cassilandia      BR -19.1133  -51.7342     60.37        16          61
# 6     Hermanus      ZA -34.4187   19.2345     47.89        68          38
# 7  Tuktoyaktuk      CA  69.4541 -133.0374     77.00        44           1
# 8    Pingliang      CN  35.5392  106.6861     65.52        91          96
# 9     Celestun      MX  20.8667  -90.4000     84.38        71           4
#
#    Wind Speed Current Description
# 0       11.12     overcast clouds
# 1        9.53     overcast clouds
# 2       12.66       broken clouds
# 3        8.32     overcast clouds
# 4        4.81    scattered clouds
# 5        4.25       broken clouds
# 6       14.88    scattered clouds
# 7       16.11           clear sky
# 8        6.20     overcast clouds
# 9       14.99           clear sky

# %%
#make this active after sure I know where it's going and its' right  I have not run this yet. check with JUSTIn first
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")

# %%
#csv files feeds into activity 2 and 3 - working well, and creating the db
