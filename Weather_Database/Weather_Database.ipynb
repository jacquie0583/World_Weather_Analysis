# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
#%pip install citipy
from citipy import citipy

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5c2f444c3abc91cc9e7680de5088257'

# %%
#cut from starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | bubaque
# Processing Record 3 of Set 1 | qasigiannguit
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | sortland
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | salalah
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | adrar
# Processing Record 15 of Set 1 | praia
# Processing Record 16 of Set 1 | hamilton
# Processing Record 17 of Set 1 | touros
# Processing Record 18 of Set 1 | barguzin
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | fairbanks
# ...

# %%
#Get the number of the cities
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bubaque  11.2833  -15.8333     81.05        80         100
# 1  Qasigiannguit  68.8193  -51.1922     48.45        80          85
# 2      Hithadhoo  -0.6000   73.0833     81.79        74         100
# 3         Castro -24.7911  -50.0119     51.62        59           6
# 4       Sortland  68.6949   15.4162     51.37        95         100
# 5       Victoria  22.2855  114.1577     82.45        92          88
# 6          Vaini -21.2000 -175.2000     82.56        69          20
# 7        Salalah  17.0151   54.0924     78.89        94          90
# 8        Rikitea -23.1203 -134.9692     73.09        58          26
# 9          Bluff -46.6000  168.3333     43.81        73          94
#
#    Wind Speed Current Description Country                 Date
# 0       12.33     overcast clouds      GW  2021-07-21 22:09:21
# 1        3.40     overcast clouds      GL  2021-07-21 22:06:12
# ...

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bubaque      GW  11.2833  -15.8333     81.05        80         100
# 1  Qasigiannguit      GL  68.8193  -51.1922     48.45        80          85
# 2      Hithadhoo      MV  -0.6000   73.0833     81.79        74         100
# 3         Castro      BR -24.7911  -50.0119     51.62        59           6
# 4       Sortland      NO  68.6949   15.4162     51.37        95         100
# 5       Victoria      HK  22.2855  114.1577     82.45        92          88
# 6          Vaini      TO -21.2000 -175.2000     82.56        69          20
# 7        Salalah      OM  17.0151   54.0924     78.89        94          90
# 8        Rikitea      PF -23.1203 -134.9692     73.09        58          26
# 9          Bluff      NZ -46.6000  168.3333     43.81        73          94
#
#    Wind Speed Current Description
# 0       12.33     overcast clouds
# 1        3.40     overcast clouds
# ...

# %%
#make this active after sure I know where it's going and its' right  I have not run this yet. check with JUSTIn first
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")

# %%
#csv files feeds into activity 2 and 3 - working well, and creating the db
